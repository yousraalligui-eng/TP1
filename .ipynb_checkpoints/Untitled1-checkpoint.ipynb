# %%
import numpy as np
import pandas as pd

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\CRISTAL\Desktop\TP1\data.csv", sep=';')

# %%
df.head()
# Out:
#   sample  value
# 0     S1   12.5
# 1     S2   15.1
# 2     S3   13.2

# %%
df.columns
# Out:
# Index(['sample', 'value'], dtype='object')

# %%
df["value"].mean()
df["value"].std()
# Out:
# np.float64(1.345362404707371)

# %%
df.plot(kind='bar', x='sample', y='value')
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: xlabel='sample'>
